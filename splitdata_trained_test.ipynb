# %%
import pandas as pd
df= pd.read_csv("train_test_dataset.csv")

# %%
df.head(10)
# Out:
#    milege  age(yr)  sellprice
# 0   69000        6      18000
# 1   35000        3      34000
# 2   57000        5      26100
# 3   22500        2      40000
# 4   46000        4      31500
# 5   59000        5      29400
# 6   52000        5      32000
# 7   72000        6      19300
# 8   91000        8      12000
# 9   67000        6      22000

# %%
import matplotlib.pyplot as plt
plt.scatter(df.milege,df.sellprice,color = 'k', marker = '*')

# %%
plt.scatter(df['age(yr)'],df.sellprice,color = 'k', marker = '*')

# %%
x = df[['milege' , 'age(yr)']]
y = df.sellprice

# %%
x
# Out:
#     milege  age(yr)
# 0    69000        6
# 1    35000        3
# 2    57000        5
# 3    22500        2
# 4    46000        4
# 5    59000        5
# 6    52000        5
# 7    72000        6
# 8    91000        8
# 9    67000        6
# 10   83000        7
# 11   79000        7
# 12   59000        5
# 13   58780        4
# 14   82450        7
# 15   25400        3
# 16   28000        2
# 17   69000        5
# 18   87600        8
# 19   52000        5

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: sellprice, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size= 0.2)

# %%
len(x_train)
# Out:
# 16

# %%
x_train
# Out:
#     milege  age(yr)
# 6    52000        5
# 16   28000        2
# 14   82450        7
# 4    46000        4
# 13   58780        4
# 2    57000        5
# 0    69000        6
# 10   83000        7
# 17   69000        5
# 9    67000        6
# 8    91000        8
# 3    22500        2
# 15   25400        3
# 1    35000        3
# 12   59000        5
# 18   87600        8

# %%
y_train
# Out:
# 6     32000
# 16    35500
# 14    19400
# 4     31500
# 13    27500
# 2     26100
# 0     18000
# 10    20000
# 17    19700
# 9     22000
# 8     12000
# 3     40000
# 15    35000
# 1     34000
# 12    33000
# 18    12800
# Name: sellprice, dtype: int64

# %%
x_test
# Out:
#     milege  age(yr)
# 11   79000        7
# 5    59000        5
# 7    72000        6
# 19   52000        5

# %%
y_test
# Out:
# 11    21000
# 5     29400
# 7     19300
# 19    28200
# Name: sellprice, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
TT = LinearRegression()

# %%
TT.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
TT.predict(x_test)
# Out:
# array([18430.68369272, 25941.63959628, 21272.11555946, 28074.41379472])

# %%
y_test
# Out:
# 11    21000
# 5     29400
# 7     19300
# 19    28200
# Name: sellprice, dtype: int64

# %%
TT.score(x_test,y_test)
# Out:
# 0.7081778906488856
