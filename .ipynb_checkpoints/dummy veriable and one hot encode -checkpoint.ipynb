# %%
# veriable have two typr in machine learning 

# nominal veriable
# a veriables which dont have relationship between each other  
# i.e. green blue black
#     male female
    
# ordinal veriable
# a verables which has relationship between each other
# i.e.  graduate 
#       master 
#       phd       graduate<master<phd

# %%
import pandas as pd
df = pd.read_csv("home.csv")

# %%
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9     robbinesville  2600  575000
# 10    robbinesville  2900  600000
# 11    robbinesville  3100  620000
# 12    robbinesville  3600  695000

# %%
# machine learning linear regression is deal with only numerical data hence first we convert town column into numberic
# we use get_dummies() method to assign dummy veriable to column

# %%
dummies = pd.get_dummies(df.town)

# %%
dummies
# Out:
#     monroe township  robbinesville  west windsor
# 0                 1              0             0
# 1                 1              0             0
# 2                 1              0             0
# 3                 1              0             0
# 4                 1              0             0
# 5                 0              0             1
# 6                 0              0             1
# 7                 0              0             1
# 8                 0              0             1
# 9                 0              1             0
# 10                0              1             0
# 11                0              1             0
# 12                0              1             0

# %%
# concate both table and drop town column so that only numeric data remaining and we need to drop one column one of theme from dummies

# %%
merged = pd.concat([df,dummies],axis = 'column')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File H:\anaconda\Lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 'column'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 merged = pd.concat([df,dummies],axis = 'column')
#
# File H:\anaconda\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...
